# %% [markdown]
# <a href="https://colab.research.google.com/github/krzysztofho/Home-Guard/blob/master/HG003_ready_model_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Install dependencies

# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib albumentations fiftyone

# %% [markdown]
# ## 1.1 Import libraries

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 2. Get and Review data
# For training models we will use cifar10 data set for classification

# %%
 test_ds, train_ds = tfds.load("cifar100", split=['test', 'train'])
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar100/3.0.2.incompleteDF0HP3/cifar100-train.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar100/3.0.2.incompleteDF0HP3/cifar100-test.tfrecord
#   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset cifar100 downloaded and prepared to /root/tensorflow_datasets/cifar100/3.0.2. Subsequent calls will reuse this data.

# %%
test_ds.as_numpy_iterator().next()
# Out:
# {'coarse_label': 8, 'id': b'test_09933', 'image': array([[[ 72,  54,  98],
#          [ 78,  59, 101],
#          [ 86,  66, 112],
#          ...,
#          [102,  82, 106],
#          [ 79,  73, 113],
#          [ 76,  70, 115]],
#
#         [[ 66,  52,  90],
#          [ 59,  50,  79],
#          [ 60,  45,  71],
#          ...,
#          [ 94,  73,  94],
#          [ 70,  60,  96],
#          [ 65,  57,  91]],
#
#         [[ 61,  50,  75],
#          [ 53,  37,  35],
#          [ 70,  42,  23],
#          ...,
#          [ 52,  38,  42],
#          [ 46,  34,  31],
#          [ 41,  31,  35]],
#
#         ...,
#
#         [[143, 104,  29],
#          [153, 108,  30],
#          [163, 120,  54],
#          ...,
#          [159, 120,  46],
#          [ 78,  97,  74],
#          [ 62,  93,  79]],
#
#         [[130, 102,  36],
#          [130, 111,  48],
#          [145, 106,  47],
#          ...,
#          [131, 106,  63],
#          [ 91,  98,  68],
#          [ 72,  93,  70]],
# ...

# %%
def get_defined_classes(row, classes=[14, 10, 12]):
  label = row['coarse_label']
  is_label = tf.equal(label, tf.cast(classes, label.dtype))
  exist = tf.reduce_max(tf.cast(is_label, tf.int8))
  return tf.cast(exist, tf.bool)

# %%
... z klass 14 wybrac las i chmury. A z klasy 12 sarny i lisy

# %%
plt.imshow(img)
